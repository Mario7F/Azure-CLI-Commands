# %% [markdown]
# <a href="https://colab.research.google.com/github/Mario7F/Azure-CLI-Commands/blob/master/TensorFlowNotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing TensorFlow Library

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd' , loss='mean_squared_error')

# %%
xs = np.array([-1.0,0.0,1.0,2.0,3.0, 4.0], dtype=float)
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0])

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 391ms/step - loss: 25.3345
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 20.2238
# Epoch 3/500
# 1/1 [==============================] - 0s 9ms/step - loss: 16.1970
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 13.0230
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 10.5201
# Epoch 6/500
# 1/1 [==============================] - 0s 12ms/step - loss: 8.5454
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9862
# Epoch 8/500
# 1/1 [==============================] - 0s 12ms/step - loss: 5.7541
# Epoch 9/500
# 1/1 [==============================] - 0s 12ms/step - loss: 4.7795
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0075
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.3950
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 160ms/step
# [[18.979757]]
